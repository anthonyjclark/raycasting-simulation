# %%
import matplotlib.pyplot as plt
import sys

sys.path.append("../PycastWorld")
sys.path.append("../Gym")

from gym_pycastworld.PycastWorldEnv import PycastWorldEnv

# %%
env = PycastWorldEnv()

# Grab the initial observation (not used here)
observation = env.reset()

# Random action selection. This should be done in some
# sort of "intelligent" manner.
action = env.action_space.sample()

# Advance the world one step. We could also have the step
# method advance more than step so that it takes fewer
# steps in total to get to the end goal.
observation, reward, done, info = env.step(action)

# Check if we reached the end goal
if done:
    print(f"  Found goal in {t+1} steps")

print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
env.close()
# Out:
#   Ended at position 3.45, 3.5000000026794895

# %%
plt.imshow(observation)

# %%
env.step(2)
env.step(2)
env.step(2)
env.step(2)
env.step(2)
observation, reward, done, info = env.step(action)

# %%
plt.imshow(observation)
print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
# Out:
#   Ended at position 3.405869811806968, 3.5319528983094086

# %%
env.step(0)
env.step(0)
env.step(0)
env.step(0)
env.step(0)
env.step(0)
observation, reward, done, info = env.step(0)

# %%
plt.imshow(observation)

# %%
observation = env.reset()

# %%
plt.imshow(observation)

# %%
dir(env.world)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'atGoal',
#  'direction',
#  'getDirX',
#  'getDirY',
#  'getTurnSpeed',
#  'getWalkSpeed',
#  'getX',
#  'getY',
#  'position',
#  'render',
#  'reset',
#  'savePNG',
#  'turn',
#  'update',
#  'walk']

# %%
env.world.position(3.5, 3.5, 0)
observation = env.reset()
plt.imshow(observation)

# %%
env.reset()
env.world.position(6.5, 3.5, 0)
observation = env.render(mode='rgb_array')
plt.imshow(observation)

# %%
observation = env.reset()

# %%
plt.axis('off')
plt.imshow(observation)
print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")

# Getting photos for forward movement
for i in range(10):    
    env.step(1)
    observation, reward, done, info = env.step(action)
    plt.imshow(observation)
    print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
    plt.savefig("Images-Marchese/Forward/forward_move" + str(i))
# Out:
#   Ended at position 3.5, 3.5
#   Ended at position 3.4000000000000004, 3.500000005358979
#   Ended at position 3.3000000000000007, 3.500000010717958
#   Ended at position 3.200000000000001, 3.500000016076937
#   Ended at position 3.1000000000000014, 3.500000021435916
#   Ended at position 3.0000000000000018, 3.500000026794895
#   Ended at position 2.900000000000002, 3.5000000321538742
#   Ended at position 2.8000000000000025, 3.5000000375128533
#   Ended at position 2.700000000000003, 3.5000000428718323
#   Ended at position 2.600000000000003, 3.5000000482308113
#   Ended at position 2.5000000000000036, 3.5000000535897904

# %%
plt.axis('off')

# Getting photos for left movement
for i in range(30):    
    env.step(0)
    observation, reward, done, info = env.step(action)
    plt.imshow(observation)
    print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
    plt.savefig("Images-Marchese/Left/left_move" + str(i))
# Out:
#   Ended at position 2.4500475888024096, 3.4978190869356425
#   Ended at position 2.4002378536578024, 3.4934613025417
#   Ended at position 2.350665610224796, 3.486934995697954
#   Ended at position 2.3014252220830476, 3.4782525895999887
#   Ended at position 2.252610421106829, 3.4674306117007236
#   Ended at position 2.204314129041081, 3.4544896622494683
#   Ended at position 2.156628280619596, 3.4394543750781783
#   Ended at position 2.1096436485620345, 3.422353370709558
#   Ended at position 2.0634496707828993, 3.40321920187627
#   Ended at position 2.0181342801413877, 3.382088291554961
#   Ended at position 1.9737837370562017, 3.3590008636330584
#   Ended at position 1.9304824653039443, 3.3340008663403156
#   Ended at position 1.8883128913136675, 3.3071358885908633
#   Ended at position 1.8473552872634857, 3.2784570693950084
#   Ended at position 1.8076876182779271, 3.2480190005132257
#   Ended at position 1.7693853940168927, 3.215879622537642
#   Ended at position 1.7325215249387325, 3.18210011459883
#   Ended at position 1.6971661835110485, 3.1467447779078594
#   Ended at position 1.6633866706334188, 3.109880913355292
#   Ended at position 1.6312472875263149, 3.0715786934001144
#   Ended at position 1.600809213330077, 3.0319110284924804
#   Ended at position 1.5721303886469487, 2.990953428284529
#   Ended at position 1.5452654052478496, 2.948783857893474
#   Ended at position 1.5202654021538415, 2.9054825894905787
#   Ended at position 1.4971779682900979, 2.861132049498519
#   Ended at position 1.4760470518976831, 2.8158166616880105
#   Ended at position 1.456912876875581, 2.769622686472366
#   Ended at position 1.439811866212219, 2.7226380567059034
#   Ended at position 1.4247765726522423, 2.6749522102987635
#   Ended at position 1.4118356167305162, 2.6266559199667725

# %%
plt.axis('off')

# Getting photos for right movement
for i in range(30):    
    env.step(2)
    observation, reward, done, info = env.step(action)
    plt.imshow(observation)
    print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
    plt.savefig("Images-Marchese/Right/right_move" + str(i))
# Out:
#   Ended at position 2.4500475890361653, 3.502181025597817
#   Ended at position 2.400237854358624, 3.5065388153303463
#   Ended at position 2.3506656116251046, 3.513065127487225
#   Ended at position 2.3014252244139333, 3.5217475388627544
#   Ended at position 2.25261042459761, 3.5325695219939695
#   Ended at position 2.2043141339188677, 3.5455104766216015
#   Ended at position 2.156628287108859, 3.560545768903841
#   Ended at position 2.1096436568841765, 3.577646778308255
#   Ended at position 2.063449681155834, 3.5967809520925944
#   Ended at position 2.018134292779125, 3.617911867270788
#   Ended at position 1.97378375216844, 3.6409992999461633
#   Ended at position 1.9304824830956722, 3.6659993018799186
#   Ended at position 1.8883129119847728, 3.6928642841490884
#   Ended at position 1.8473553110083751, 3.721543107734762
#   Ended at position 1.8076876452851562, 3.7519811808681087
#   Ended at position 1.7693854244688072, 3.7841205629489085
#   Ended at position 1.732521559011121, 3.8179000748387746
#   Ended at position 1.6971662213728076, 3.853255415319116
#   Ended at position 1.663386712446232, 3.8901192834921576
#   Ended at position 1.6312473334443442, 3.9284215068920205
#   Ended at position 1.6008092634996705, 3.968089175061994
#   Ended at position 1.5721304432063608, 4.00904677834373
#   Ended at position 1.545265464326979, 4.051216351614162
#   Ended at position 1.5202654658739831, 4.094517622696547
#   Ended at position 1.4971780367637122, 4.1388681651631085
#   Ended at position 1.4760471252281822, 4.18418355523842
#   Ended at position 1.4569129551571312, 4.230377532504857
#   Ended at position 1.4398119495295623, 4.277362164104199
#   Ended at position 1.4247766610805348, 4.3250480121228145
#   Ended at position 1.4118357103351853, 4.373344303841812
