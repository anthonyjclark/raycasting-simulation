# %%
import matplotlib.pyplot as plt

import sys

sys.path.append("../PycastWorld")
sys.path.append("../Gym")

from gym_pycastworld.PycastWorldEnv import PycastWorldEnv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-aaf308254d5a> in <module>
#       6 sys.path.append("../Gym")
#       7
# ----> 8 from gym_pycastworld.PycastWorldEnv import PycastWorldEnv
#
# ~/arcslab/raycasting-simulation/Notebooks/../Gym/gym_pycastworld/PycastWorldEnv.py in <module>
#      15 from typing import Dict, List, Tuple
#      16
# ---> 17 from pycaster import PycastWorld, Turn, Walk  # type: ignore
#      18
#      19
#
# ModuleNotFoundError: No module named 'pycaster'

# %%
env = PycastWorldEnv()

# Grab the initial observation (not used here)
observation = env.reset()

# Random action selection. This should be done in some
# sort of "intelligent" manner.
action = env.action_space.sample()

# Advance the world one step. We could also have the step
# method advance more than step so that it takes fewer
# steps in total to get to the end goal.
observation, reward, done, info = env.step(action)

# Check if we reached the end goal
if done:
    print(f"  Found goal in {t+1} steps")

print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-21df3067b098> in <module>
# ----> 1 env = PycastWorldEnv()
#       2
#       3 # Grab the initial observation (not used here)
#       4 observation = env.reset()
#       5
#
# NameError: name 'PycastWorldEnv' is not defined

# %%
plt.imshow(observation)

# %%
env.step(1)
env.step(1)
env.step(1)
env.step(1)
env.step(1)
env.step(1)
observation, reward, done, info = env.step(action)

# %%
plt.imshow(observation)
print(f"  Ended at position {env.world.getX()}, {env.world.getY()}")
# Out:
#   Ended at position 2.700000000000003, 3.5000000428718323

# %%
env.step(0)
env.step(0)
env.step(0)
env.step(0)
env.step(0)
env.step(0)
observation, reward, done, info = env.step(0)

# %%
plt.imshow(observation)

# %%
observation = env.reset()

# %%
plt.imshow(observation)

# %%
dir(env.world)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'atGoal',
#  'direction',
#  'getDirX',
#  'getDirY',
#  'getTurnSpeed',
#  'getWalkSpeed',
#  'getX',
#  'getY',
#  'position',
#  'render',
#  'reset',
#  'savePNG',
#  'turn',
#  'update',
#  'walk']

# %%
env.world.position(3.5, 3.5, 0)
observation = env.reset()
plt.imshow(observation)

# %%
env.reset()
env.world.position(6.5, 3.5, 0)
observation = env.render(mode='rgb_array')
plt.imshow(observation)
