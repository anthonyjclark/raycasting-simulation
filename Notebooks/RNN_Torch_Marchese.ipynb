# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import convLSTM as convLSTM
from pathlib import Path
from time import time
from PIL import Image
from RNN_classes_funcs_Marchese import *
# Out:
# /home/CAMPUS/cemb2020/anaconda3/envs/arcslab/lib/python3.8/site-packages/fastbook/__init__.py:18: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=3)

# %%
# Get classes and filenames
path = Path("data_RNN")
classes = get_classes(path)
all_filenames = get_filenames(path)
all_filenames.sort()

# %%
# Getting size of dataset and corresponding list of indices
dataset_size = len(all_filenames)
dataset_indices = list(range(dataset_size))

# %%
# Getting index for where we want to split the data
val_split_index = int(np.floor(0.2 * dataset_size))

# %%
# Splitting list of indices into training and validation indices
train_idx, val_idx = dataset_indices[val_split_index:], dataset_indices[:val_split_index]

# %%
# Getting list of filenames for training and validation set
train_filenames = [all_filenames[i] for i in train_idx]
val_filenames = [all_filenames[i] for i in val_idx]
train_filenames
# Out:
# [Path('data_RNN/01390-straight-straight.png'),
#  Path('data_RNN/01391-straight-straight.png'),
#  Path('data_RNN/01392-straight-straight.png'),
#  Path('data_RNN/01393-straight-straight.png'),
#  Path('data_RNN/01394-straight-straight.png'),
#  Path('data_RNN/01395-straight-straight.png'),
#  Path('data_RNN/01396-straight-straight.png'),
#  Path('data_RNN/01397-straight-straight.png'),
#  Path('data_RNN/01398-straight-straight.png'),
#  Path('data_RNN/01399-straight-straight.png'),
#  Path('data_RNN/01400-straight-straight.png'),
#  Path('data_RNN/01401-straight-straight.png'),
#  Path('data_RNN/01402-straight-straight.png'),
#  Path('data_RNN/01403-straight-straight.png'),
#  Path('data_RNN/01404-straight-straight.png'),
#  Path('data_RNN/01405-straight-straight.png'),
#  Path('data_RNN/01406-straight-straight.png'),
#  Path('data_RNN/01407-straight-straight.png'),
#  Path('data_RNN/01408-straight-straight.png'),
#  Path('data_RNN/01409-straight-straight.png'),
#  Path('data_RNN/01410-straight-straight.png'),
#  Path('data_RNN/01411-straight-straight.png'),
#  Path('data_RNN/01412-straight-straight.png'),
#  Path('data_RNN/01413-straight-straight.png'),
#  Path('data_RNN/01414-straight-straight.png'),
#  Path('data_RNN/01415-straight-straight.png'),
#  Path('data_RNN/01416-right-straight.png'),
#  Path('data_RNN/01417-right-right.png'),
#  Path('data_RNN/01418-right-right.png'),
#  Path('data_RNN/01419-right-right.png'),
#  Path('data_RNN/01420-right-right.png'),
#  Path('data_RNN/01421-right-right.png'),
#  Path('data_RNN/01422-right-right.png'),
#  Path('data_RNN/01423-right-right.png'),
#  Path('data_RNN/01424-right-right.png'),
#  Path('data_RNN/01425-right-right.png'),
#  Path('data_RNN/01426-right-right.png'),
#  Path('data_RNN/01427-right-right.png'),
#  Path('data_RNN/01428-straight-right.png'),
#  Path('data_RNN/01429-straight-straight.png'),
#  Path('data_RNN/01430-straight-straight.png'),
#  Path('data_RNN/01431-straight-straight.png'),
#  Path('data_RNN/01432-straight-straight.png'),
#  Path('data_RNN/01433-straight-straight.png'),
#  Path('data_RNN/01434-straight-straight.png'),
#  Path('data_RNN/01435-straight-straight.png'),
#  Path('data_RNN/01436-straight-straight.png'),
#  Path('data_RNN/01437-straight-straight.png'),
#  Path('data_RNN/01438-left-straight.png'),
#  Path('data_RNN/01439-left-left.png'),
#  Path('data_RNN/01440-left-left.png'),
#  Path('data_RNN/01441-left-left.png'),
#  Path('data_RNN/01442-left-left.png'),
#  Path('data_RNN/01443-left-left.png'),
#  Path('data_RNN/01444-left-left.png'),
#  Path('data_RNN/01445-left-left.png'),
#  Path('data_RNN/01446-left-left.png'),
#  Path('data_RNN/01447-left-left.png'),
#  Path('data_RNN/01448-left-left.png'),
#  Path('data_RNN/01449-left-left.png'),
#  Path('data_RNN/01450-left-left.png'),
#  Path('data_RNN/01451-left-left.png'),
#  Path('data_RNN/01452-left-left.png'),
#  Path('data_RNN/01453-left-left.png'),
#  Path('data_RNN/01454-left-left.png'),
#  Path('data_RNN/01455-left-left.png'),
#  Path('data_RNN/01456-left-left.png'),
#  Path('data_RNN/01457-left-left.png'),
#  Path('data_RNN/01458-left-left.png'),
#  Path('data_RNN/01459-left-left.png'),
#  Path('data_RNN/01460-left-left.png'),
#  Path('data_RNN/01461-left-left.png'),
#  Path('data_RNN/01462-left-left.png'),
#  Path('data_RNN/01463-left-left.png'),
#  Path('data_RNN/01464-left-left.png'),
#  Path('data_RNN/01465-left-left.png'),
#  Path('data_RNN/01466-left-left.png'),
#  Path('data_RNN/01467-left-left.png'),
#  Path('data_RNN/01468-left-left.png'),
#  Path('data_RNN/01469-left-left.png'),
#  Path('data_RNN/01470-left-left.png'),
#  Path('data_RNN/01471-left-left.png'),
#  Path('data_RNN/01472-straight-left.png'),
#  Path('data_RNN/01473-straight-straight.png'),
#  Path('data_RNN/01474-straight-straight.png'),
#  Path('data_RNN/01475-straight-straight.png'),
#  Path('data_RNN/01476-straight-straight.png'),
#  Path('data_RNN/01477-straight-straight.png'),
#  Path('data_RNN/01478-straight-straight.png'),
#  Path('data_RNN/01479-straight-straight.png'),
#  Path('data_RNN/01480-straight-straight.png'),
#  Path('data_RNN/01481-straight-straight.png'),
#  Path('data_RNN/01482-straight-straight.png'),
#  Path('data_RNN/01483-straight-straight.png'),
#  Path('data_RNN/01484-straight-straight.png'),
#  Path('data_RNN/01485-straight-straight.png'),
#  Path('data_RNN/01486-straight-straight.png'),
#  Path('data_RNN/01487-straight-straight.png'),
#  Path('data_RNN/01488-straight-straight.png'),
#  Path('data_RNN/01489-straight-straight.png'),
#  Path('data_RNN/01490-straight-straight.png'),
#  Path('data_RNN/01491-straight-straight.png'),
#  Path('data_RNN/01492-straight-straight.png'),
#  Path('data_RNN/01493-straight-straight.png'),
#  Path('data_RNN/01494-straight-straight.png'),
#  Path('data_RNN/01495-straight-straight.png'),
#  Path('data_RNN/01496-straight-straight.png'),
#  Path('data_RNN/01497-straight-straight.png'),
#  Path('data_RNN/01498-straight-straight.png'),
#  Path('data_RNN/01499-straight-straight.png'),
#  Path('data_RNN/01500-straight-straight.png'),
#  Path('data_RNN/01501-straight-straight.png'),
#  Path('data_RNN/01502-right-straight.png'),
#  Path('data_RNN/01503-right-right.png'),
#  Path('data_RNN/01504-right-right.png'),
#  Path('data_RNN/01505-right-right.png'),
#  Path('data_RNN/01506-right-right.png'),
#  Path('data_RNN/01507-right-right.png'),
#  Path('data_RNN/01508-right-right.png'),
#  Path('data_RNN/01509-right-right.png'),
#  Path('data_RNN/01510-right-right.png'),
#  Path('data_RNN/01511-right-right.png'),
#  Path('data_RNN/01512-right-right.png'),
#  Path('data_RNN/01513-right-right.png'),
#  Path('data_RNN/01514-right-right.png'),
#  Path('data_RNN/01515-right-right.png'),
#  Path('data_RNN/01516-right-right.png'),
#  Path('data_RNN/01517-right-right.png'),
#  Path('data_RNN/01518-right-right.png'),
#  Path('data_RNN/01519-right-right.png'),
#  Path('data_RNN/01520-straight-right.png'),
#  Path('data_RNN/01521-straight-straight.png'),
#  Path('data_RNN/01522-straight-straight.png'),
#  Path('data_RNN/01523-straight-straight.png'),
#  Path('data_RNN/01524-straight-straight.png'),
#  Path('data_RNN/01525-straight-straight.png'),
#  Path('data_RNN/01526-straight-straight.png'),
#  Path('data_RNN/01527-straight-straight.png'),
#  Path('data_RNN/01528-straight-straight.png'),
#  Path('data_RNN/01529-straight-straight.png'),
#  Path('data_RNN/01530-straight-straight.png'),
#  Path('data_RNN/01531-straight-straight.png'),
#  Path('data_RNN/01532-straight-straight.png'),
#  Path('data_RNN/01533-straight-straight.png'),
#  Path('data_RNN/01534-straight-straight.png'),
#  Path('data_RNN/01535-straight-straight.png'),
#  Path('data_RNN/01536-straight-straight.png'),
#  Path('data_RNN/01537-straight-straight.png'),
#  Path('data_RNN/01538-straight-straight.png'),
#  Path('data_RNN/01539-straight-straight.png'),
#  Path('data_RNN/01540-straight-straight.png'),
#  Path('data_RNN/01541-straight-straight.png'),
#  Path('data_RNN/01542-straight-straight.png'),
#  Path('data_RNN/01543-straight-straight.png'),
#  Path('data_RNN/01544-straight-straight.png'),
#  Path('data_RNN/01545-straight-straight.png'),
#  Path('data_RNN/01546-straight-straight.png'),
#  Path('data_RNN/01547-straight-straight.png'),
#  Path('data_RNN/01548-straight-straight.png'),
#  Path('data_RNN/01549-straight-straight.png'),
#  Path('data_RNN/01550-straight-straight.png'),
#  Path('data_RNN/01551-left-straight.png'),
#  Path('data_RNN/01552-left-left.png'),
#  Path('data_RNN/01553-left-left.png'),
#  Path('data_RNN/01554-left-left.png'),
#  Path('data_RNN/01555-left-left.png'),
#  Path('data_RNN/01556-left-left.png'),
#  Path('data_RNN/01557-left-left.png'),
#  Path('data_RNN/01558-left-left.png'),
#  Path('data_RNN/01559-left-left.png'),
#  Path('data_RNN/01560-left-left.png'),
#  Path('data_RNN/01561-left-left.png'),
#  Path('data_RNN/01562-left-left.png'),
#  Path('data_RNN/01563-left-left.png'),
#  Path('data_RNN/01564-left-left.png'),
#  Path('data_RNN/01565-left-left.png'),
#  Path('data_RNN/01566-left-left.png'),
#  Path('data_RNN/01567-left-left.png'),
#  Path('data_RNN/01568-left-left.png'),
#  Path('data_RNN/01569-left-left.png'),
#  Path('data_RNN/01570-left-left.png'),
#  Path('data_RNN/01571-left-left.png'),
#  Path('data_RNN/01572-left-left.png'),
#  Path('data_RNN/01573-left-left.png'),
#  Path('data_RNN/01574-left-left.png'),
#  Path('data_RNN/01575-straight-left.png'),
#  Path('data_RNN/01576-straight-straight.png'),
#  Path('data_RNN/01577-straight-straight.png'),
#  Path('data_RNN/01578-straight-straight.png'),
#  Path('data_RNN/01579-straight-straight.png'),
#  Path('data_RNN/01580-straight-straight.png'),
#  Path('data_RNN/01581-straight-straight.png'),
#  Path('data_RNN/01582-straight-straight.png'),
#  Path('data_RNN/01583-straight-straight.png'),
#  Path('data_RNN/01584-straight-straight.png'),
#  Path('data_RNN/01585-straight-straight.png'),
#  Path('data_RNN/01586-straight-straight.png'),
#  Path('data_RNN/01587-straight-straight.png'),
#  Path('data_RNN/01588-straight-straight.png'),
#  Path('data_RNN/01589-straight-straight.png'),
#  Path('data_RNN/01590-straight-straight.png'),
#  Path('data_RNN/01591-straight-straight.png'),
#  Path('data_RNN/01592-straight-straight.png'),
#  Path('data_RNN/01593-straight-straight.png'),
#  Path('data_RNN/01594-straight-straight.png'),
#  Path('data_RNN/01595-straight-straight.png'),
#  Path('data_RNN/01596-straight-straight.png'),
#  Path('data_RNN/01597-straight-straight.png'),
#  Path('data_RNN/01598-straight-straight.png'),
#  Path('data_RNN/01599-straight-straight.png'),
#  Path('data_RNN/01600-straight-straight.png'),
#  Path('data_RNN/01601-straight-straight.png'),
#  Path('data_RNN/01602-straight-straight.png'),
#  Path('data_RNN/01603-straight-straight.png'),
#  Path('data_RNN/01604-left-straight.png'),
#  Path('data_RNN/01605-left-left.png'),
#  Path('data_RNN/01606-left-left.png'),
#  Path('data_RNN/01607-left-left.png'),
#  Path('data_RNN/01608-left-left.png'),
#  Path('data_RNN/01609-left-left.png'),
#  Path('data_RNN/01610-left-left.png'),
#  Path('data_RNN/01611-left-left.png'),
#  Path('data_RNN/01612-left-left.png'),
#  Path('data_RNN/01613-left-left.png'),
#  Path('data_RNN/01614-left-left.png'),
#  Path('data_RNN/01615-left-left.png'),
#  Path('data_RNN/01616-left-left.png'),
#  Path('data_RNN/01617-left-left.png'),
#  Path('data_RNN/01618-left-left.png'),
#  Path('data_RNN/01619-left-left.png'),
#  Path('data_RNN/01620-left-left.png'),
#  Path('data_RNN/01621-left-left.png'),
#  Path('data_RNN/01622-left-left.png'),
#  Path('data_RNN/01623-left-left.png'),
#  Path('data_RNN/01624-left-left.png'),
#  Path('data_RNN/01625-left-left.png'),
#  Path('data_RNN/01626-left-left.png'),
#  Path('data_RNN/01627-left-left.png'),
#  Path('data_RNN/01628-left-left.png'),
#  Path('data_RNN/01629-left-left.png'),
#  Path('data_RNN/01630-left-left.png'),
#  Path('data_RNN/01631-left-left.png'),
#  Path('data_RNN/01632-left-left.png'),
#  Path('data_RNN/01633-left-left.png'),
#  Path('data_RNN/01634-left-left.png'),
#  Path('data_RNN/01635-straight-left.png'),
#  Path('data_RNN/01636-straight-straight.png'),
#  Path('data_RNN/01637-straight-straight.png'),
#  Path('data_RNN/01638-straight-straight.png'),
#  Path('data_RNN/01639-straight-straight.png'),
#  Path('data_RNN/01640-straight-straight.png'),
#  Path('data_RNN/01641-straight-straight.png'),
#  Path('data_RNN/01642-straight-straight.png'),
#  Path('data_RNN/01643-straight-straight.png'),
#  Path('data_RNN/01644-straight-straight.png'),
#  Path('data_RNN/01645-straight-straight.png'),
#  Path('data_RNN/01646-straight-straight.png'),
#  Path('data_RNN/01647-straight-straight.png'),
#  Path('data_RNN/01648-straight-straight.png'),
#  Path('data_RNN/01649-straight-straight.png'),
#  Path('data_RNN/01650-straight-straight.png'),
#  Path('data_RNN/01651-straight-straight.png'),
#  Path('data_RNN/01652-straight-straight.png'),
#  Path('data_RNN/01653-straight-straight.png'),
#  Path('data_RNN/01654-straight-straight.png'),
#  Path('data_RNN/01655-straight-straight.png'),
#  Path('data_RNN/01656-straight-straight.png'),
#  Path('data_RNN/01657-straight-straight.png'),
#  Path('data_RNN/01658-straight-straight.png'),
#  Path('data_RNN/01659-straight-straight.png'),
#  Path('data_RNN/01660-straight-straight.png'),
#  Path('data_RNN/01661-straight-straight.png'),
#  Path('data_RNN/01662-straight-straight.png'),
#  Path('data_RNN/01663-straight-straight.png'),
#  Path('data_RNN/01664-straight-straight.png'),
#  Path('data_RNN/01665-straight-straight.png'),
#  Path('data_RNN/01666-right-straight.png'),
#  Path('data_RNN/01667-right-right.png'),
#  Path('data_RNN/01668-right-right.png'),
#  Path('data_RNN/01669-right-right.png'),
#  Path('data_RNN/01670-right-right.png'),
#  Path('data_RNN/01671-right-right.png'),
#  Path('data_RNN/01672-right-right.png'),
#  Path('data_RNN/01673-right-right.png'),
#  Path('data_RNN/01674-right-right.png'),
#  Path('data_RNN/01675-right-right.png'),
#  Path('data_RNN/01676-right-right.png'),
#  Path('data_RNN/01677-right-right.png'),
#  Path('data_RNN/01678-right-right.png'),
#  Path('data_RNN/01679-right-right.png'),
#  Path('data_RNN/01680-right-right.png'),
#  Path('data_RNN/01681-right-right.png'),
#  Path('data_RNN/01682-right-right.png'),
#  Path('data_RNN/01683-right-right.png'),
#  Path('data_RNN/01684-right-right.png'),
#  Path('data_RNN/01685-right-right.png'),
#  Path('data_RNN/01686-right-right.png'),
#  Path('data_RNN/01687-right-right.png'),
#  Path('data_RNN/01688-right-right.png'),
#  Path('data_RNN/01689-right-right.png'),
#  Path('data_RNN/01690-straight-right.png'),
#  Path('data_RNN/01691-straight-straight.png'),
#  Path('data_RNN/01692-straight-straight.png'),
#  Path('data_RNN/01693-straight-straight.png'),
#  Path('data_RNN/01694-straight-straight.png'),
#  Path('data_RNN/01695-straight-straight.png'),
#  Path('data_RNN/01696-straight-straight.png'),
#  Path('data_RNN/01697-straight-straight.png'),
#  Path('data_RNN/01698-straight-straight.png'),
#  Path('data_RNN/01699-straight-straight.png'),
#  Path('data_RNN/01700-straight-straight.png'),
#  Path('data_RNN/01701-straight-straight.png'),
#  Path('data_RNN/01702-straight-straight.png'),
#  Path('data_RNN/01703-straight-straight.png'),
#  Path('data_RNN/01704-straight-straight.png'),
#  Path('data_RNN/01705-straight-straight.png'),
#  Path('data_RNN/01706-straight-straight.png'),
#  Path('data_RNN/01707-straight-straight.png'),
#  Path('data_RNN/01708-straight-straight.png'),
#  Path('data_RNN/01709-straight-straight.png'),
#  Path('data_RNN/01710-straight-straight.png'),
#  Path('data_RNN/01711-straight-straight.png'),
#  Path('data_RNN/01712-straight-straight.png'),
#  Path('data_RNN/01713-straight-straight.png'),
#  Path('data_RNN/01714-straight-straight.png'),
#  Path('data_RNN/01715-straight-straight.png'),
#  Path('data_RNN/01716-straight-straight.png'),
#  Path('data_RNN/01717-straight-straight.png'),
#  Path('data_RNN/01718-straight-straight.png'),
#  Path('data_RNN/01719-right-straight.png'),
#  Path('data_RNN/01720-right-right.png'),
#  Path('data_RNN/01721-right-right.png'),
#  Path('data_RNN/01722-right-right.png'),
#  Path('data_RNN/01723-right-right.png'),
#  Path('data_RNN/01724-right-right.png'),
#  Path('data_RNN/01725-right-right.png'),
#  Path('data_RNN/01726-right-right.png'),
#  Path('data_RNN/01727-right-right.png'),
#  Path('data_RNN/01728-right-right.png'),
#  Path('data_RNN/01729-right-right.png'),
#  Path('data_RNN/01730-right-right.png'),
#  Path('data_RNN/01731-right-right.png'),
#  Path('data_RNN/01732-right-right.png'),
#  Path('data_RNN/01733-right-right.png'),
#  Path('data_RNN/01734-right-right.png'),
#  Path('data_RNN/01735-right-right.png'),
#  Path('data_RNN/01736-right-right.png'),
#  Path('data_RNN/01737-right-right.png'),
#  Path('data_RNN/01738-right-right.png'),
#  Path('data_RNN/01739-right-right.png'),
#  Path('data_RNN/01740-right-right.png'),
#  Path('data_RNN/01741-right-right.png'),
#  Path('data_RNN/01742-right-right.png'),
#  Path('data_RNN/01743-right-right.png'),
#  Path('data_RNN/01744-right-right.png'),
#  Path('data_RNN/01745-right-right.png'),
#  Path('data_RNN/01746-right-right.png'),
#  Path('data_RNN/01747-right-right.png'),
#  Path('data_RNN/01748-right-right.png'),
#  Path('data_RNN/01749-right-right.png'),
#  Path('data_RNN/01750-right-right.png'),
#  Path('data_RNN/01751-right-right.png'),
#  Path('data_RNN/01752-right-right.png'),
#  Path('data_RNN/01753-right-right.png'),
#  Path('data_RNN/01754-straight-right.png'),
#  Path('data_RNN/01755-straight-straight.png'),
#  Path('data_RNN/01756-straight-straight.png'),
#  Path('data_RNN/01757-straight-straight.png'),
#  Path('data_RNN/01758-straight-straight.png'),
#  Path('data_RNN/01759-straight-straight.png'),
#  Path('data_RNN/01760-straight-straight.png'),
#  Path('data_RNN/01761-straight-straight.png'),
#  Path('data_RNN/01762-straight-straight.png'),
#  Path('data_RNN/01763-straight-straight.png'),
#  Path('data_RNN/01764-straight-straight.png'),
#  Path('data_RNN/01765-straight-straight.png'),
#  Path('data_RNN/01766-straight-straight.png'),
#  Path('data_RNN/01767-straight-straight.png'),
#  Path('data_RNN/01768-straight-straight.png'),
#  Path('data_RNN/01769-straight-straight.png'),
#  Path('data_RNN/01770-straight-straight.png'),
#  Path('data_RNN/01771-straight-straight.png'),
#  Path('data_RNN/01772-straight-straight.png'),
#  Path('data_RNN/01773-straight-straight.png'),
#  Path('data_RNN/01774-left-straight.png'),
#  Path('data_RNN/01775-left-left.png'),
#  Path('data_RNN/01776-straight-left.png'),
#  Path('data_RNN/01777-straight-straight.png'),
#  Path('data_RNN/01778-straight-straight.png'),
#  Path('data_RNN/01779-straight-straight.png'),
#  Path('data_RNN/01780-straight-straight.png'),
#  Path('data_RNN/01781-straight-straight.png'),
#  Path('data_RNN/01782-straight-straight.png'),
#  Path('data_RNN/01783-straight-straight.png'),
#  Path('data_RNN/01784-straight-straight.png'),
#  Path('data_RNN/01785-straight-straight.png'),
#  Path('data_RNN/01786-straight-straight.png'),
#  Path('data_RNN/01787-left-straight.png'),
#  Path('data_RNN/01788-left-left.png'),
#  Path('data_RNN/01789-left-left.png'),
#  Path('data_RNN/01790-left-left.png'),
#  Path('data_RNN/01791-left-left.png'),
#  Path('data_RNN/01792-left-left.png'),
#  Path('data_RNN/01793-left-left.png'),
#  Path('data_RNN/01794-left-left.png'),
#  Path('data_RNN/01795-left-left.png'),
#  Path('data_RNN/01796-left-left.png'),
#  Path('data_RNN/01797-left-left.png'),
#  Path('data_RNN/01798-left-left.png'),
#  Path('data_RNN/01799-left-left.png'),
#  Path('data_RNN/01800-left-left.png'),
#  Path('data_RNN/01801-left-left.png'),
#  Path('data_RNN/01802-left-left.png'),
#  Path('data_RNN/01803-left-left.png'),
#  Path('data_RNN/01804-left-left.png'),
#  Path('data_RNN/01805-left-left.png'),
#  Path('data_RNN/01806-left-left.png'),
#  Path('data_RNN/01807-left-left.png'),
#  Path('data_RNN/01808-left-left.png'),
#  Path('data_RNN/01809-straight-left.png'),
#  Path('data_RNN/01810-straight-straight.png'),
#  Path('data_RNN/01811-straight-straight.png'),
#  Path('data_RNN/01812-straight-straight.png'),
#  Path('data_RNN/01813-straight-straight.png'),
#  Path('data_RNN/01814-straight-straight.png'),
#  Path('data_RNN/01815-straight-straight.png'),
#  Path('data_RNN/01816-straight-straight.png'),
#  Path('data_RNN/01817-straight-straight.png'),
#  Path('data_RNN/01818-straight-straight.png'),
#  Path('data_RNN/01819-left-straight.png'),
#  Path('data_RNN/01820-straight-left.png'),
#  Path('data_RNN/01821-straight-straight.png'),
#  Path('data_RNN/01822-straight-straight.png'),
#  Path('data_RNN/01823-straight-straight.png'),
#  Path('data_RNN/01824-straight-straight.png'),
#  Path('data_RNN/01825-straight-straight.png'),
#  Path('data_RNN/01826-straight-straight.png'),
#  Path('data_RNN/01827-straight-straight.png'),
#  Path('data_RNN/01828-straight-straight.png'),
#  Path('data_RNN/01829-straight-straight.png'),
#  Path('data_RNN/01830-straight-straight.png'),
#  Path('data_RNN/01831-straight-straight.png'),
#  Path('data_RNN/01832-straight-straight.png'),
#  Path('data_RNN/01833-straight-straight.png'),
#  Path('data_RNN/01834-straight-straight.png'),
#  Path('data_RNN/01835-straight-straight.png'),
#  Path('data_RNN/01836-straight-straight.png'),
#  Path('data_RNN/01837-straight-straight.png'),
#  Path('data_RNN/01838-straight-straight.png'),
#  Path('data_RNN/01839-straight-straight.png'),
#  Path('data_RNN/01840-straight-straight.png'),
#  Path('data_RNN/01841-straight-straight.png'),
#  Path('data_RNN/01842-straight-straight.png'),
#  Path('data_RNN/01843-straight-straight.png'),
#  Path('data_RNN/01844-left-straight.png'),
#  Path('data_RNN/01845-left-left.png'),
#  Path('data_RNN/01846-left-left.png'),
#  Path('data_RNN/01847-left-left.png'),
#  Path('data_RNN/01848-left-left.png'),
#  Path('data_RNN/01849-left-left.png'),
#  Path('data_RNN/01850-straight-left.png'),
#  Path('data_RNN/01851-straight-straight.png'),
#  Path('data_RNN/01852-straight-straight.png'),
#  Path('data_RNN/01853-straight-straight.png'),
#  Path('data_RNN/01854-straight-straight.png'),
#  Path('data_RNN/01855-straight-straight.png'),
#  Path('data_RNN/01856-straight-straight.png'),
#  Path('data_RNN/01857-straight-straight.png'),
#  Path('data_RNN/01858-straight-straight.png'),
#  Path('data_RNN/01859-straight-straight.png'),
#  Path('data_RNN/01860-straight-straight.png'),
#  Path('data_RNN/01861-straight-straight.png'),
#  Path('data_RNN/01862-straight-straight.png'),
#  Path('data_RNN/01863-straight-straight.png'),
#  Path('data_RNN/01864-straight-straight.png'),
#  Path('data_RNN/01865-straight-straight.png'),
#  Path('data_RNN/01866-straight-straight.png'),
#  Path('data_RNN/01867-straight-straight.png'),
#  Path('data_RNN/01868-straight-straight.png'),
#  Path('data_RNN/01869-straight-straight.png'),
#  Path('data_RNN/01870-straight-straight.png'),
#  Path('data_RNN/01871-straight-straight.png'),
#  Path('data_RNN/01872-straight-straight.png'),
#  Path('data_RNN/01873-straight-straight.png'),
#  Path('data_RNN/01874-straight-straight.png'),
#  Path('data_RNN/01875-straight-straight.png'),
#  Path('data_RNN/01876-straight-straight.png'),
#  Path('data_RNN/01877-straight-straight.png'),
#  Path('data_RNN/01878-straight-straight.png'),
#  Path('data_RNN/01879-straight-straight.png'),
#  Path('data_RNN/01880-straight-straight.png'),
#  Path('data_RNN/01881-straight-straight.png'),
#  Path('data_RNN/01882-straight-straight.png'),
#  Path('data_RNN/01883-straight-straight.png'),
#  Path('data_RNN/01884-straight-straight.png'),
#  Path('data_RNN/01885-straight-straight.png'),
#  Path('data_RNN/01886-straight-straight.png'),
#  Path('data_RNN/01887-straight-straight.png'),
#  Path('data_RNN/01888-straight-straight.png'),
#  Path('data_RNN/01889-straight-straight.png'),
#  Path('data_RNN/01890-left-straight.png'),
#  Path('data_RNN/01891-left-left.png'),
#  Path('data_RNN/01892-left-left.png'),
#  Path('data_RNN/01893-left-left.png'),
#  Path('data_RNN/01894-left-left.png'),
#  Path('data_RNN/01895-left-left.png'),
#  Path('data_RNN/01896-left-left.png'),
#  Path('data_RNN/01897-left-left.png'),
#  Path('data_RNN/01898-left-left.png'),
#  Path('data_RNN/01899-left-left.png'),
#  Path('data_RNN/01900-left-left.png'),
#  Path('data_RNN/01901-left-left.png'),
#  Path('data_RNN/01902-left-left.png'),
#  Path('data_RNN/01903-left-left.png'),
#  Path('data_RNN/01904-left-left.png'),
#  Path('data_RNN/01905-left-left.png'),
#  Path('data_RNN/01906-left-left.png'),
#  Path('data_RNN/01907-left-left.png'),
#  Path('data_RNN/01908-left-left.png'),
#  Path('data_RNN/01909-left-left.png'),
#  Path('data_RNN/01910-left-left.png'),
#  Path('data_RNN/01911-left-left.png'),
#  Path('data_RNN/01912-left-left.png'),
#  Path('data_RNN/01913-left-left.png'),
#  Path('data_RNN/01914-left-left.png'),
#  Path('data_RNN/01915-left-left.png'),
#  Path('data_RNN/01916-left-left.png'),
#  Path('data_RNN/01917-left-left.png'),
#  Path('data_RNN/01918-left-left.png'),
#  Path('data_RNN/01919-left-left.png'),
#  Path('data_RNN/01920-left-left.png'),
#  Path('data_RNN/01921-left-left.png'),
#  Path('data_RNN/01922-left-left.png'),
#  Path('data_RNN/01923-straight-left.png'),
#  Path('data_RNN/01924-straight-straight.png'),
#  Path('data_RNN/01925-straight-straight.png'),
#  Path('data_RNN/01926-straight-straight.png'),
#  Path('data_RNN/01927-straight-straight.png'),
#  Path('data_RNN/01928-straight-straight.png'),
#  Path('data_RNN/01929-straight-straight.png'),
#  Path('data_RNN/01930-straight-straight.png'),
#  Path('data_RNN/01931-straight-straight.png'),
#  Path('data_RNN/01932-straight-straight.png'),
#  Path('data_RNN/01933-straight-straight.png'),
#  Path('data_RNN/01934-straight-straight.png'),
#  Path('data_RNN/01935-straight-straight.png'),
#  Path('data_RNN/01936-straight-straight.png'),
#  Path('data_RNN/01937-straight-straight.png'),
#  Path('data_RNN/01938-straight-straight.png'),
#  Path('data_RNN/01939-straight-straight.png'),
#  Path('data_RNN/01940-straight-straight.png'),
#  Path('data_RNN/01941-straight-straight.png'),
#  Path('data_RNN/01942-straight-straight.png'),
#  Path('data_RNN/01943-straight-straight.png'),
#  Path('data_RNN/01944-straight-straight.png'),
#  Path('data_RNN/01945-straight-straight.png'),
#  Path('data_RNN/01946-straight-straight.png'),
#  Path('data_RNN/01947-straight-straight.png'),
#  Path('data_RNN/01948-straight-straight.png'),
#  Path('data_RNN/01949-straight-straight.png'),
#  Path('data_RNN/01950-straight-straight.png'),
#  Path('data_RNN/01951-straight-straight.png'),
#  Path('data_RNN/01952-straight-straight.png'),
#  Path('data_RNN/01953-straight-straight.png'),
#  Path('data_RNN/01954-straight-straight.png'),
#  Path('data_RNN/01955-straight-straight.png'),
#  Path('data_RNN/01956-straight-straight.png'),
#  Path('data_RNN/01957-left-straight.png'),
#  Path('data_RNN/01958-straight-left.png'),
#  Path('data_RNN/01959-straight-straight.png'),
#  Path('data_RNN/01960-straight-straight.png'),
#  Path('data_RNN/01961-straight-straight.png'),
#  Path('data_RNN/01962-straight-straight.png'),
#  Path('data_RNN/01963-straight-straight.png'),
#  Path('data_RNN/01964-straight-straight.png'),
#  Path('data_RNN/01965-straight-straight.png'),
#  Path('data_RNN/01966-straight-straight.png'),
#  Path('data_RNN/01967-straight-straight.png'),
#  Path('data_RNN/01968-straight-straight.png'),
#  Path('data_RNN/01969-straight-straight.png'),
#  Path('data_RNN/01970-straight-straight.png'),
#  Path('data_RNN/01971-straight-straight.png'),
#  Path('data_RNN/01972-straight-straight.png'),
#  Path('data_RNN/01973-straight-straight.png'),
#  Path('data_RNN/01974-straight-straight.png'),
#  Path('data_RNN/01975-straight-straight.png'),
#  Path('data_RNN/01976-straight-straight.png'),
#  Path('data_RNN/01977-straight-straight.png'),
#  Path('data_RNN/01978-straight-straight.png'),
#  Path('data_RNN/01979-straight-straight.png'),
#  Path('data_RNN/01980-straight-straight.png'),
#  Path('data_RNN/01981-straight-straight.png'),
#  Path('data_RNN/01982-straight-straight.png'),
#  Path('data_RNN/01983-straight-straight.png'),
#  Path('data_RNN/01984-straight-straight.png'),
#  Path('data_RNN/01985-straight-straight.png'),
#  Path('data_RNN/01986-straight-straight.png'),
#  Path('data_RNN/01987-straight-straight.png'),
#  Path('data_RNN/01988-straight-straight.png'),
#  Path('data_RNN/01989-straight-straight.png'),
#  Path('data_RNN/01990-straight-straight.png'),
#  Path('data_RNN/01991-straight-straight.png'),
#  Path('data_RNN/01992-left-straight.png'),
#  Path('data_RNN/01993-left-left.png'),
#  Path('data_RNN/01994-straight-left.png'),
#  Path('data_RNN/01995-straight-straight.png'),
#  Path('data_RNN/01996-straight-straight.png'),
#  Path('data_RNN/01997-straight-straight.png'),
#  Path('data_RNN/01998-straight-straight.png'),
#  Path('data_RNN/01999-straight-straight.png'),
#  Path('data_RNN/02000-left-straight.png'),
#  Path('data_RNN/02001-left-left.png'),
#  Path('data_RNN/02002-left-left.png'),
#  Path('data_RNN/02003-left-left.png'),
#  Path('data_RNN/02004-left-left.png'),
#  Path('data_RNN/02005-left-left.png'),
#  Path('data_RNN/02006-left-left.png'),
#  Path('data_RNN/02007-left-left.png'),
#  Path('data_RNN/02008-left-left.png'),
#  Path('data_RNN/02009-left-left.png'),
#  Path('data_RNN/02010-left-left.png'),
#  Path('data_RNN/02011-left-left.png'),
#  Path('data_RNN/02012-left-left.png'),
#  Path('data_RNN/02013-left-left.png'),
#  Path('data_RNN/02014-left-left.png'),
#  Path('data_RNN/02015-left-left.png'),
#  Path('data_RNN/02016-left-left.png'),
#  Path('data_RNN/02017-left-left.png'),
#  Path('data_RNN/02018-left-left.png'),
#  Path('data_RNN/02019-left-left.png'),
#  Path('data_RNN/02020-left-left.png'),
#  Path('data_RNN/02021-left-left.png'),
#  Path('data_RNN/02022-left-left.png'),
#  Path('data_RNN/02023-left-left.png'),
#  Path('data_RNN/02024-left-left.png'),
#  Path('data_RNN/02025-left-left.png'),
#  Path('data_RNN/02026-left-left.png'),
#  Path('data_RNN/02027-left-left.png'),
#  Path('data_RNN/02028-left-left.png'),
#  Path('data_RNN/02029-straight-left.png'),
#  Path('data_RNN/02030-straight-straight.png'),
#  Path('data_RNN/02031-straight-straight.png'),
#  Path('data_RNN/02032-straight-straight.png'),
#  Path('data_RNN/02033-straight-straight.png'),
#  Path('data_RNN/02034-straight-straight.png'),
#  Path('data_RNN/02035-straight-straight.png'),
#  Path('data_RNN/02036-straight-straight.png'),
#  Path('data_RNN/02037-straight-straight.png'),
#  Path('data_RNN/02038-straight-straight.png'),
#  Path('data_RNN/02039-straight-straight.png'),
#  Path('data_RNN/02040-straight-straight.png'),
#  Path('data_RNN/02041-straight-straight.png'),
#  Path('data_RNN/02042-straight-straight.png'),
#  Path('data_RNN/02043-straight-straight.png'),
#  Path('data_RNN/02044-straight-straight.png'),
#  Path('data_RNN/02045-straight-straight.png'),
#  Path('data_RNN/02046-straight-straight.png'),
#  Path('data_RNN/02047-straight-straight.png'),
#  Path('data_RNN/02048-straight-straight.png'),
#  Path('data_RNN/02049-straight-straight.png'),
#  Path('data_RNN/02050-straight-straight.png'),
#  Path('data_RNN/02051-straight-straight.png'),
#  Path('data_RNN/02052-straight-straight.png'),
#  Path('data_RNN/02053-straight-straight.png'),
#  Path('data_RNN/02054-straight-straight.png'),
#  Path('data_RNN/02055-straight-straight.png'),
#  Path('data_RNN/02056-straight-straight.png'),
#  Path('data_RNN/02057-left-straight.png'),
#  Path('data_RNN/02058-left-left.png'),
#  Path('data_RNN/02059-left-left.png'),
#  Path('data_RNN/02060-left-left.png'),
#  Path('data_RNN/02061-left-left.png'),
#  Path('data_RNN/02062-left-left.png'),
#  Path('data_RNN/02063-straight-left.png'),
#  Path('data_RNN/02064-straight-straight.png'),
#  Path('data_RNN/02065-straight-straight.png'),
#  Path('data_RNN/02066-straight-straight.png'),
#  Path('data_RNN/02067-straight-straight.png'),
#  Path('data_RNN/02068-straight-straight.png'),
#  Path('data_RNN/02069-straight-straight.png'),
#  Path('data_RNN/02070-straight-straight.png'),
#  Path('data_RNN/02071-straight-straight.png'),
#  Path('data_RNN/02072-straight-straight.png'),
#  Path('data_RNN/02073-straight-straight.png'),
#  Path('data_RNN/02074-straight-straight.png'),
#  Path('data_RNN/02075-straight-straight.png'),
#  Path('data_RNN/02076-straight-straight.png'),
#  Path('data_RNN/02077-straight-straight.png'),
#  Path('data_RNN/02078-straight-straight.png'),
#  Path('data_RNN/02079-straight-straight.png'),
#  Path('data_RNN/02080-straight-straight.png'),
#  Path('data_RNN/02081-straight-straight.png'),
#  Path('data_RNN/02082-straight-straight.png'),
#  Path('data_RNN/02083-straight-straight.png'),
#  Path('data_RNN/02084-straight-straight.png'),
#  Path('data_RNN/02085-straight-straight.png'),
#  Path('data_RNN/02086-straight-straight.png'),
#  Path('data_RNN/02087-straight-straight.png'),
#  Path('data_RNN/02088-straight-straight.png'),
#  Path('data_RNN/02089-straight-straight.png'),
#  Path('data_RNN/02090-straight-straight.png'),
#  Path('data_RNN/02091-straight-straight.png'),
#  Path('data_RNN/02092-straight-straight.png'),
#  Path('data_RNN/02093-straight-straight.png'),
#  Path('data_RNN/02094-straight-straight.png'),
#  Path('data_RNN/02095-straight-straight.png'),
#  Path('data_RNN/02096-straight-straight.png'),
#  Path('data_RNN/02097-straight-straight.png'),
#  Path('data_RNN/02098-straight-straight.png'),
#  Path('data_RNN/02099-straight-straight.png'),
#  Path('data_RNN/02100-straight-straight.png'),
#  Path('data_RNN/02101-straight-straight.png'),
#  Path('data_RNN/02102-straight-straight.png'),
#  Path('data_RNN/02103-straight-straight.png'),
#  Path('data_RNN/02104-straight-straight.png'),
#  Path('data_RNN/02105-straight-straight.png'),
#  Path('data_RNN/02106-straight-straight.png'),
#  Path('data_RNN/02107-straight-straight.png'),
#  Path('data_RNN/02108-straight-straight.png'),
#  Path('data_RNN/02109-straight-straight.png'),
#  Path('data_RNN/02110-straight-straight.png'),
#  Path('data_RNN/02111-straight-straight.png'),
#  Path('data_RNN/02112-straight-straight.png'),
#  Path('data_RNN/02113-straight-straight.png'),
#  Path('data_RNN/02114-straight-straight.png'),
#  Path('data_RNN/02115-straight-straight.png'),
#  Path('data_RNN/02116-straight-straight.png'),
#  Path('data_RNN/02117-straight-straight.png'),
#  Path('data_RNN/02118-straight-straight.png'),
#  Path('data_RNN/02119-straight-straight.png'),
#  Path('data_RNN/02120-straight-straight.png'),
#  Path('data_RNN/02121-straight-straight.png'),
#  Path('data_RNN/02122-straight-straight.png'),
#  Path('data_RNN/02123-straight-straight.png'),
#  Path('data_RNN/02124-straight-straight.png'),
#  Path('data_RNN/02125-straight-straight.png'),
#  Path('data_RNN/02126-straight-straight.png'),
#  Path('data_RNN/02127-straight-straight.png'),
#  Path('data_RNN/02128-straight-straight.png'),
#  Path('data_RNN/02129-straight-straight.png'),
#  Path('data_RNN/02130-straight-straight.png'),
#  Path('data_RNN/02131-straight-straight.png'),
#  Path('data_RNN/02132-straight-straight.png'),
#  Path('data_RNN/02133-straight-straight.png'),
#  Path('data_RNN/02134-straight-straight.png'),
#  Path('data_RNN/02135-straight-straight.png'),
#  Path('data_RNN/02136-straight-straight.png'),
#  Path('data_RNN/02137-straight-straight.png'),
#  Path('data_RNN/02138-straight-straight.png'),
#  Path('data_RNN/02139-straight-straight.png'),
#  Path('data_RNN/02140-straight-straight.png'),
#  Path('data_RNN/02141-straight-straight.png'),
#  Path('data_RNN/02142-straight-straight.png'),
#  Path('data_RNN/02143-straight-straight.png'),
#  Path('data_RNN/02144-straight-straight.png'),
#  Path('data_RNN/02145-straight-straight.png'),
#  Path('data_RNN/02146-straight-straight.png'),
#  Path('data_RNN/02147-straight-straight.png'),
#  Path('data_RNN/02148-straight-straight.png'),
#  Path('data_RNN/02149-straight-straight.png'),
#  Path('data_RNN/02150-straight-straight.png'),
#  Path('data_RNN/02151-straight-straight.png'),
#  Path('data_RNN/02152-straight-straight.png'),
#  Path('data_RNN/02153-straight-straight.png'),
#  Path('data_RNN/02154-straight-straight.png'),
#  Path('data_RNN/02155-straight-straight.png'),
#  Path('data_RNN/02156-straight-straight.png'),
#  Path('data_RNN/02157-straight-straight.png'),
#  Path('data_RNN/02158-straight-straight.png'),
#  Path('data_RNN/02159-straight-straight.png'),
#  Path('data_RNN/02160-straight-straight.png'),
#  Path('data_RNN/02161-straight-straight.png'),
#  Path('data_RNN/02162-straight-straight.png'),
#  Path('data_RNN/02163-straight-straight.png'),
#  Path('data_RNN/02164-straight-straight.png'),
#  Path('data_RNN/02165-straight-straight.png'),
#  Path('data_RNN/02166-straight-straight.png'),
#  Path('data_RNN/02167-straight-straight.png'),
#  Path('data_RNN/02168-straight-straight.png'),
#  Path('data_RNN/02169-straight-straight.png'),
#  Path('data_RNN/02170-straight-straight.png'),
#  Path('data_RNN/02171-straight-straight.png'),
#  Path('data_RNN/02172-straight-straight.png'),
#  Path('data_RNN/02173-straight-straight.png'),
#  Path('data_RNN/02174-straight-straight.png'),
#  Path('data_RNN/02175-straight-straight.png'),
#  Path('data_RNN/02176-straight-straight.png'),
#  Path('data_RNN/02177-straight-straight.png'),
#  Path('data_RNN/02178-straight-straight.png'),
#  Path('data_RNN/02179-left-straight.png'),
#  Path('data_RNN/02180-left-left.png'),
#  Path('data_RNN/02181-left-left.png'),
#  Path('data_RNN/02182-left-left.png'),
#  Path('data_RNN/02183-straight-left.png'),
#  Path('data_RNN/02184-straight-straight.png'),
#  Path('data_RNN/02185-straight-straight.png'),
#  Path('data_RNN/02186-straight-straight.png'),
#  Path('data_RNN/02187-straight-straight.png'),
#  Path('data_RNN/02188-straight-straight.png'),
#  Path('data_RNN/02189-straight-straight.png'),
#  Path('data_RNN/02190-straight-straight.png'),
#  Path('data_RNN/02191-straight-straight.png'),
#  Path('data_RNN/02192-straight-straight.png'),
#  Path('data_RNN/02193-right-straight.png'),
#  Path('data_RNN/02194-right-right.png'),
#  Path('data_RNN/02195-right-right.png'),
#  Path('data_RNN/02196-right-right.png'),
#  Path('data_RNN/02197-right-right.png'),
#  Path('data_RNN/02198-right-right.png'),
#  Path('data_RNN/02199-right-right.png'),
#  Path('data_RNN/02200-right-right.png'),
#  Path('data_RNN/02201-right-right.png'),
#  Path('data_RNN/02202-right-right.png'),
#  Path('data_RNN/02203-right-right.png'),
#  Path('data_RNN/02204-right-right.png'),
#  Path('data_RNN/02205-right-right.png'),
#  Path('data_RNN/02206-right-right.png'),
#  Path('data_RNN/02207-right-right.png'),
#  Path('data_RNN/02208-right-right.png'),
#  Path('data_RNN/02209-right-right.png'),
#  Path('data_RNN/02210-right-right.png'),
#  Path('data_RNN/02211-right-right.png'),
#  Path('data_RNN/02212-right-right.png'),
#  Path('data_RNN/02213-right-right.png'),
#  Path('data_RNN/02214-right-right.png'),
#  Path('data_RNN/02215-right-right.png'),
#  Path('data_RNN/02216-right-right.png'),
#  Path('data_RNN/02217-right-right.png'),
#  Path('data_RNN/02218-right-right.png'),
#  Path('data_RNN/02219-right-right.png'),
#  Path('data_RNN/02220-right-right.png'),
#  Path('data_RNN/02221-right-right.png'),
#  Path('data_RNN/02222-right-right.png'),
#  Path('data_RNN/02223-right-right.png'),
#  Path('data_RNN/02224-right-right.png'),
#  Path('data_RNN/02225-right-right.png'),
#  Path('data_RNN/02226-right-right.png'),
#  Path('data_RNN/02227-right-right.png'),
#  Path('data_RNN/02228-right-right.png'),
#  Path('data_RNN/02229-right-right.png'),
#  Path('data_RNN/02230-right-right.png'),
#  Path('data_RNN/02231-left-right.png'),
#  Path('data_RNN/02232-right-left.png'),
#  Path('data_RNN/02233-left-right.png'),
#  Path('data_RNN/02234-left-left.png'),
#  Path('data_RNN/02235-left-left.png'),
#  Path('data_RNN/02236-left-left.png'),
#  Path('data_RNN/02237-right-left.png'),
#  Path('data_RNN/02238-right-right.png'),
#  Path('data_RNN/02239-right-right.png'),
#  Path('data_RNN/02240-right-right.png'),
#  Path('data_RNN/02241-left-right.png'),
#  Path('data_RNN/02242-left-left.png'),
#  Path('data_RNN/02243-right-left.png'),
#  Path('data_RNN/02244-right-right.png'),
#  Path('data_RNN/02245-right-right.png'),
#  Path('data_RNN/02246-right-right.png'),
#  Path('data_RNN/02247-straight-right.png'),
#  Path('data_RNN/02248-straight-straight.png'),
#  Path('data_RNN/02249-straight-straight.png'),
#  Path('data_RNN/02250-straight-straight.png'),
#  Path('data_RNN/02251-straight-straight.png'),
#  Path('data_RNN/02252-straight-straight.png'),
#  Path('data_RNN/02253-straight-straight.png'),
#  Path('data_RNN/02254-straight-straight.png'),
#  Path('data_RNN/02255-straight-straight.png'),
#  Path('data_RNN/02256-straight-straight.png'),
#  Path('data_RNN/02257-straight-straight.png'),
#  Path('data_RNN/02258-straight-straight.png'),
#  Path('data_RNN/02259-straight-straight.png'),
#  Path('data_RNN/02260-straight-straight.png'),
#  Path('data_RNN/02261-straight-straight.png'),
#  Path('data_RNN/02262-straight-straight.png'),
#  Path('data_RNN/02263-straight-straight.png'),
#  Path('data_RNN/02264-straight-straight.png'),
#  Path('data_RNN/02265-straight-straight.png'),
#  Path('data_RNN/02266-straight-straight.png'),
#  Path('data_RNN/02267-straight-straight.png'),
#  Path('data_RNN/02268-straight-straight.png'),
#  Path('data_RNN/02269-straight-straight.png'),
#  Path('data_RNN/02270-straight-straight.png'),
#  Path('data_RNN/02271-straight-straight.png'),
#  Path('data_RNN/02272-straight-straight.png'),
#  Path('data_RNN/02273-straight-straight.png'),
#  Path('data_RNN/02274-straight-straight.png'),
#  Path('data_RNN/02275-right-straight.png'),
#  Path('data_RNN/02276-right-right.png'),
#  Path('data_RNN/02277-right-right.png'),
#  Path('data_RNN/02278-right-right.png'),
#  Path('data_RNN/02279-right-right.png'),
#  Path('data_RNN/02280-right-right.png'),
#  Path('data_RNN/02281-right-right.png'),
#  Path('data_RNN/02282-right-right.png'),
#  Path('data_RNN/02283-right-right.png'),
#  Path('data_RNN/02284-right-right.png'),
#  Path('data_RNN/02285-right-right.png'),
#  Path('data_RNN/02286-right-right.png'),
#  Path('data_RNN/02287-right-right.png'),
#  Path('data_RNN/02288-right-right.png'),
#  Path('data_RNN/02289-right-right.png'),
#  Path('data_RNN/02290-right-right.png'),
#  Path('data_RNN/02291-right-right.png'),
#  Path('data_RNN/02292-right-right.png'),
#  Path('data_RNN/02293-right-right.png'),
#  Path('data_RNN/02294-right-right.png'),
#  Path('data_RNN/02295-right-right.png'),
#  Path('data_RNN/02296-right-right.png'),
#  Path('data_RNN/02297-right-right.png'),
#  Path('data_RNN/02298-right-right.png'),
#  Path('data_RNN/02299-right-right.png'),
#  Path('data_RNN/02300-right-right.png'),
#  Path('data_RNN/02301-right-right.png'),
#  Path('data_RNN/02302-right-right.png'),
#  Path('data_RNN/02303-straight-right.png'),
#  Path('data_RNN/02304-straight-straight.png'),
#  Path('data_RNN/02305-straight-straight.png'),
#  Path('data_RNN/02306-straight-straight.png'),
#  Path('data_RNN/02307-straight-straight.png'),
#  Path('data_RNN/02308-straight-straight.png'),
#  Path('data_RNN/02309-straight-straight.png'),
#  Path('data_RNN/02310-straight-straight.png'),
#  Path('data_RNN/02311-straight-straight.png'),
#  Path('data_RNN/02312-straight-straight.png'),
#  Path('data_RNN/02313-right-straight.png'),
#  Path('data_RNN/02314-straight-right.png'),
#  Path('data_RNN/02315-straight-straight.png'),
#  Path('data_RNN/02316-straight-straight.png'),
#  Path('data_RNN/02317-straight-straight.png'),
#  Path('data_RNN/02318-straight-straight.png'),
#  Path('data_RNN/02319-straight-straight.png'),
#  Path('data_RNN/02320-straight-straight.png'),
#  Path('data_RNN/02321-straight-straight.png'),
#  Path('data_RNN/02322-straight-straight.png'),
#  Path('data_RNN/02323-straight-straight.png'),
#  Path('data_RNN/02324-straight-straight.png'),
#  Path('data_RNN/02325-straight-straight.png'),
#  Path('data_RNN/02326-right-straight.png'),
#  Path('data_RNN/02327-right-right.png'),
#  Path('data_RNN/02328-straight-right.png'),
#  Path('data_RNN/02329-straight-straight.png'),
#  Path('data_RNN/02330-straight-straight.png'),
#  Path('data_RNN/02331-right-straight.png'),
#  Path('data_RNN/02332-right-right.png'),
#  Path('data_RNN/02333-right-right.png'),
#  Path('data_RNN/02334-right-right.png'),
#  Path('data_RNN/02335-right-right.png'),
#  Path('data_RNN/02336-straight-right.png'),
#  Path('data_RNN/02337-straight-straight.png'),
#  Path('data_RNN/02338-straight-straight.png'),
#  Path('data_RNN/02339-straight-straight.png'),
#  Path('data_RNN/02340-straight-straight.png'),
#  Path('data_RNN/02341-straight-straight.png'),
#  Path('data_RNN/02342-straight-straight.png'),
#  Path('data_RNN/02343-straight-straight.png'),
#  Path('data_RNN/02344-straight-straight.png'),
#  Path('data_RNN/02345-straight-straight.png'),
#  Path('data_RNN/02346-straight-straight.png'),
#  Path('data_RNN/02347-straight-straight.png'),
#  Path('data_RNN/02348-straight-straight.png'),
#  Path('data_RNN/02349-straight-straight.png'),
#  Path('data_RNN/02350-straight-straight.png'),
#  Path('data_RNN/02351-straight-straight.png'),
#  Path('data_RNN/02352-straight-straight.png'),
#  Path('data_RNN/02353-straight-straight.png'),
#  Path('data_RNN/02354-straight-straight.png'),
#  Path('data_RNN/02355-straight-straight.png'),
#  Path('data_RNN/02356-straight-straight.png'),
#  Path('data_RNN/02357-straight-straight.png'),
#  Path('data_RNN/02358-straight-straight.png'),
#  Path('data_RNN/02359-straight-straight.png'),
#  Path('data_RNN/02360-straight-straight.png'),
#  Path('data_RNN/02361-straight-straight.png'),
#  Path('data_RNN/02362-straight-straight.png'),
#  Path('data_RNN/02363-straight-straight.png'),
#  Path('data_RNN/02364-straight-straight.png'),
#  Path('data_RNN/02365-straight-straight.png'),
#  Path('data_RNN/02366-straight-straight.png'),
#  Path('data_RNN/02367-straight-straight.png'),
#  Path('data_RNN/02368-straight-straight.png'),
#  Path('data_RNN/02369-straight-straight.png'),
#  Path('data_RNN/02370-straight-straight.png'),
#  Path('data_RNN/02371-straight-straight.png'),
#  Path('data_RNN/02372-straight-straight.png'),
#  Path('data_RNN/02373-straight-straight.png'),
#  Path('data_RNN/02374-left-straight.png'),
#  Path('data_RNN/02375-left-left.png'),
#  Path('data_RNN/02376-left-left.png'),
#  Path('data_RNN/02377-left-left.png'),
#  Path('data_RNN/02378-left-left.png'),
#  Path('data_RNN/02379-left-left.png'),
#  Path('data_RNN/02380-straight-left.png'),
#  Path('data_RNN/02381-straight-straight.png'),
#  Path('data_RNN/02382-right-straight.png'),
#  Path('data_RNN/02383-straight-right.png'),
#  Path('data_RNN/02384-straight-straight.png'),
#  Path('data_RNN/02385-straight-straight.png'),
#  Path('data_RNN/02386-straight-straight.png'),
#  Path('data_RNN/02387-straight-straight.png'),
#  Path('data_RNN/02388-straight-straight.png'),
#  Path('data_RNN/02389-straight-straight.png'),
#  ...]

# %%
# Getting data via custom dataset
train_data = ImageDataset(classes, train_filenames)
val_data = ImageDataset(classes, val_filenames)

# %%
# Loading in data
train_loader = DataLoader(dataset=train_data, shuffle=False, batch_size=8)
val_loader = DataLoader(dataset=val_data, shuffle=False, batch_size=8)
img, label = next(iter(train_loader))

# %%
img.size()
# Out:
# torch.Size([8, 1, 3, 240, 320])

# %%
net = ConvRNN()
net.to(device)
# Out:
# ConvRNN(
#   (convlstm): ConvLSTM(
#     (cell_list): ModuleList(
#       (0): ConvLSTMCell(
#         (conv): Conv2d(13, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=768000, out_features=512, bias=True)
#   (relu): ReLU()
#   (lin2): Linear(in_features=512, out_features=3, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.0001)

# %%
num_epochs = 20

# %%
net.train()

for epoch in range(num_epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    
    start = time()
    
    for data in train_loader:
        # Get the inputs and labels; currently ommitting cmd
        img, label = data
        
        # Putting data into the GPU
        img = img.to(device)
        label = label.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        output = net(img)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        
    print(f"Epoch:{epoch+1:}/{num_epochs}, Training Loss:{running_loss:0.1f}, Time:{time()-start:0.1f}s")

print('Finished Training')
# Out:
# Epoch:1/20, Training Loss:546.6, Time:63.6s
# Epoch:2/20, Training Loss:350.6, Time:63.2s
# Epoch:3/20, Training Loss:339.7, Time:63.0s
# Epoch:4/20, Training Loss:288.5, Time:63.8s
# Epoch:5/20, Training Loss:241.2, Time:63.3s
# Epoch:6/20, Training Loss:217.0, Time:63.5s
# Epoch:7/20, Training Loss:189.3, Time:64.3s
# Epoch:8/20, Training Loss:143.5, Time:64.6s
# Epoch:9/20, Training Loss:113.3, Time:64.6s
# Epoch:10/20, Training Loss:88.9, Time:64.2s
# Epoch:11/20, Training Loss:60.5, Time:64.5s
# Epoch:12/20, Training Loss:39.5, Time:64.5s
# Epoch:13/20, Training Loss:43.1, Time:63.9s
# Epoch:14/20, Training Loss:30.0, Time:64.8s
# Epoch:15/20, Training Loss:12.1, Time:63.3s
# Epoch:16/20, Training Loss:8.1, Time:62.6s
# Epoch:17/20, Training Loss:7.1, Time:64.5s
# Epoch:18/20, Training Loss:7.2, Time:64.8s
# Epoch:19/20, Training Loss:10.1, Time:63.9s
# Epoch:20/20, Training Loss:29.9, Time:64.4s
# Finished Training

# %%
# Checking accuracy on validation set

correct = 0
total = 0

# Variables to keep track of accuracy for each class
class_correct = [0 for _ in classes]
class_total = [0 for _ in classes]

net.eval()

with torch.no_grad():

    for data in val_loader:

        # Get the inputs and labels; currently ommitting cmd
        img, label = data
        
        # Putting data into the GPU
        img = img.to(device)
        label = label.to(device)


        # Predict
        output = net(img)
        
        # Assuming we always get batches
        for i in range(output.size()[0]):
                
            # Getting the predicted most probable move
            move = torch.argmax(output[i])
                
            if move == label[i]:
                class_correct[label[i]] += 1
                class_total[label[i]] += 1
                correct +=1
            else:
                class_total[label[i]] += 1
            total += 1
        
# Calculate and output total set accuracy 
accuracy = correct / total
print(f"Accuracy on validation set: {correct}/{total} = {accuracy*100:.2f}%")

# Calculate and show accuracy for each class
for i, cls in enumerate(classes):
    ccorrect = class_correct[i]
    ctotal = class_total[i]
    caccuracy = ccorrect / ctotal
    print(f"  Accuracy on {cls:>5} class: {ccorrect}/{ctotal} = {caccuracy*100:.2f}%")
# Out:
# Accuracy on validation set: 1111/1389 = 79.99%
#   Accuracy on  left class: 112/143 = 78.32%
#   Accuracy on right class: 233/283 = 82.33%
#   Accuracy on straight class: 766/963 = 79.54%

# %%
PATH = 'torch_RNN.pth'
torch.save(net.state_dict(), PATH)
